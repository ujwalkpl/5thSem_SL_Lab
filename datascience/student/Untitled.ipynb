# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                         NaN      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                         NaN      standard
#
#   test preparation course  mathscore  reading score  writing score
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'mathscore', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.drop(columns=['lunch','test preparation course'])
# Out:
#      gender race/ethnicity parental level of education  mathscore  \
# 0    female        group B           bachelor's degree         72
# 1    female        group C                         NaN         69
# 2    female        group B             master's degree         90
# 3      male        group A          associate's degree         47
# 4      male        group C                         NaN         76
# 5    female        group B          associate's degree         71
# 6    female        group B                         NaN         88
# 7      male        group B                         NaN         40
# 8      male        group D                 high school         64
# 9    female        group B                 high school         38
# 10     male        group C          associate's degree         58
# 11     male        group D          associate's degree         40
# 12   female        group B                 high school         65
# ...

# %%
df['race/ethnicity']=df['race/ethnicity'].map({'group A':'Asian Students','group B':'African Students','group C':'Afro-Asian Students','group D':'American Students','group E':'European Students'})

# %%
nedf=pd.crosstab(df['gender'],df['race/ethnicity'])
sns.countplot(data=nedf,x='gender')
# Out:
# race/ethnicity  group A  group B  group C  group D  group E
# gender
# female               36      104      180      129       69
# male                 53       86      139      133       71

# %%
intervals=[0,40,50,60,74,100]
categories=['<40','40-50','50-60','60-74','74>']
df['categories']=pd.cut(df['mathscore'],intervals,categories,include_lowest=True)
sns.countplot(data=df,x=categories,hue)
